# %% [markdown]
# Hello My name is Philip Glenn.  I'm excited to learn more python to help in my current role in Cybersecurity.  I'm looking forward to learning more about automation and how it can best support my team.

# %%
year = input("What year is it? ")
print ("Excited to be here in", year , "!")
# Out:
# Excited to be here in 2026 !
